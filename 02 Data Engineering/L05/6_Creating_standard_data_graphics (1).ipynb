# %% [markdown]
# ## Segment 1 - Creating standard data graphics

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
# x = range(1,10)
# y = [1,2,3,4,0,4,3,2,1]
#
# plt.plot(x,y)

x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
# cars = pd.read_csv('mtcars.csv')
cars = pd.read_csv('./mtcars.csv')
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
mpg = cars['mpg']

# %%
mpg.plot()
# Out:
# <Axes: >

# %%
# df = cars[['cyl','wt','mpg']]
# df.plot()

df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind="bar")
# Out:
# <Axes: >

# %%
mpg.plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# ### Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving a plot

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()

# %%
# %pwd
# Out:
# 'C:\\Users\\zhang\\Documents\\Programming\\DataAnalysis-Learning\\02 Data Engineering\\L05'
